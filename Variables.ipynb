# %% [markdown]
# # Variables and variable types
#
# ## "Regular" variables
#
# 1. strings
# 1. integers
# 1. floats
#
# ## "Collection" variables
#
# 1. tuples
# 1. lists
# 1. sets
# 1. dictionaries
#
# From https://www.w3schools.com:
#
# - **Strings** are for storing text
# - **Integers** are for storing whole numbers, positive or negative (such as 123 or -456), without decimals.
# - **Floats** are for storing positive and negative numbers with a decimal point, like 35.3, or -2.34
# - **Lists** are collections which are ordered and changeable. Allows duplicate members.
# - **Tuples** are collections which are ordered and unchangeable. Allows duplicate members.
# - **Sets** are collections which are unordered, "unchangeable", and unindexed. No duplicate members.
# - **Dictionaries** are collections which are ordered and changeable. No duplicate members.

# %% [markdown]
# ## Strings

# %%
name = 'String'

# %% [markdown]
# ## Integers

# %%
number = 18

# %% [markdown]
# ## Floats

# %%
new_number = 18.92

# %% [markdown]
# ## Lists

# %% [markdown]
# List of numbers or variables, can change numbers and numbers can be there multiple times. Use [] to define

# %%
first_list = [3, 2, 78, 2]
first_list[1]
first_list[2]
first_list[1]=5
first_list
# Out:
# [3, 5, 78, 2]

# %%
second_list = [name, number, new_number]
second_list
# Out:
# ['String', 18, 18.92]

# %% [markdown]
# ## Tuples

# %% [markdown]
# Collections (,) similiar to list but you cannot change an item

# %%
shopping_list = ["apples", "pears", "bananas"]
shopping_tuple = ("apples", "pears", "banana")

# %%
shopping_list[1]
# Out:
# 'pears'

# %%
shopping_tuple[1]
# Out:
# 'pears'

# %% [markdown]
# ## Sets

# %%
Sets are unordered, canot be changed and you cannot have duplicate members. Ordered "alphabetically". Use {} to define

# %%
new_list = [4, 4, 7, 19, 21, 'a string', 7.28]
my_set = set(new_list)
my_set
# Out:
# {19, 21, 4, 7, 7.28, 'a string'}

# %%
my_next_set = {3, 5, 7}
my_next_set
# Out:
# {3, 5, 7}

# %%
last_set = set(first_list)
last_set
# Out:
# {2, 3, 5, 78}

# %% [markdown]
# ## Dictionaries

# %%
my_pet = {'name': 'D2',
          'species': 'cat',
          'likes': 'sleeping',
          'dislikes': 'loud noises',
          'age':10}

# %%
my_pet['age']
# Out:
# 10

# %%
items = ['grapes', 'skyr', ['salt', 'pepper', 'cumin'], 'rice']
number = [1, 2, 7, 3]
priority = ['high', 'high' 'low', 'high']

# %%
shopping = {'items': items, 
            'number': number, 
            'priority': priority}

# %%
shopping['items']
# Out:
# ['grapes', 'skyr', ['salt', 'pepper', 'cumin'], 'rice']

# %%
shopping['items'][2]
# Out:
# ['salt', 'pepper', 'cumin']

# %%
##Lists

monkeys=['macaque', 'baboon', 'tamarin']

# %%
apes=['gibbon', 'chimpanzee', 'gorilla']

# %%
primates={'apes', 'monkeys'}

# %%
a = [4, 5, 8]

# %% [markdown]
# Slicing, type, len, pandas dataframes

# %%
type(a)
# Out:
# list

# %%
type(primates)
# Out:
# set

# %%
len(a)
# Out:
# 3

# %%
len('monkeys')
# Out:
# 7

# %%
a = [4,5,8,5,8,9,2]

# %%
a[3:]
# Out:
# [5, 8, 9, 2]

# %%
a[0]
# Out:
# 4

# %%
len(a)
# Out:
# 7

# %%
a[-1]
# Out:
# 2
